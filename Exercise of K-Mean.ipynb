# %%
#apply K-mean clustering
#applay Kmeans with k=3

Kmeans=KMeans(n_clusters=3,random_state=42)
Kmeans.fit(X)



#Get labels and cluster centers
labels=Kmeans.labels_
centers=Kmeans.cluster_centers_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#1- create list f k (1-10)
#2- create empty list to store score, name it score_lst

k=[1,2,3,4,5,7,8,9,10]
score_list=[]
label_list=[]

#3- loop in k:
#       - create Kmeab model
#        - fit model
#        - get score * (Silhouette score)

k=list(range(1,11))
for k in k:
  Kmeans=KMeans(n_clusters=k,random_state=42)
  Kmeans.fit(X)
  score=silhouette_score(X,labels)
  #append to score_lst
  score_list.append(score)
print(score_list)


labels_=Kmeans.labels_
centers=Kmeans.cluster_centers_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cd1147ede841> in <cell line: 14>()
#      15   Kmeans=KMeans(n_clusters=k,random_state=42)
#      16   Kmeans.fit(X)
# ---> 17   score=silhouette_score(X,labels)
#      18   #append to score_lst
#      19   score_list.append(score)
#
# NameError: name 'labels' is not defined

# %%
print(score_list)
# Out:
# []

# %%
#visulize the clusters
plt.scatter(X[:,0],X[:,1], c=labels,cmap='viridis')
plt.scatter(centers[:, 0], centers[: ,1], c='red',s=200 ,alpha=0.5)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.title('K-Means Clusting with k=10')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-68617e91df3f> in <cell line: 2>()
#       1 #visulize the clusters
# ----> 2 plt.scatter(X[:,0],X[:,1], c=labels,cmap='viridis')
#       3 plt.scatter(centers[:, 0], centers[: ,1], c='red',s=200 ,alpha=0.5)
#       4 plt.xlabel('Petal length')
#       5 plt.ylabel('Petal width')
#
# NameError: name 'labels' is not defined
